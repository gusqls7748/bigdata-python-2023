# %% [markdown]
# #### 맷플롯립
#
# 시각화 도구 모듈. 다양한 차트를 활용
# - 공식 웹사이트 : https://matplotlib.org/
#
# 맷플롯립 대체 모듈
# - Seaborn : https://seaborn.pydata.org/
#
# #### 맥플롯립 설치
#
# - matplotlib inline (기본으로 설치되어 있음)
#
# %matplotlib inline
#     ㅡmatplotlib 설치
#  !pip install matplotlib

# %%
# !pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#      -                                        0.3/7.6 MB 6.3 MB/s eta 0:00:02
#      ----                                     0.8/7.6 MB 8.3 MB/s eta 0:00:01
#      -------                                  1.4/7.6 MB 9.7 MB/s eta 0:00:01
#      -----------                              2.1/7.6 MB 11.3 MB/s eta 0:00:01
#      ----------------                         3.1/7.6 MB 13.3 MB/s eta 0:00:01
#      ----------------------                   4.3/7.6 MB 15.4 MB/s eta 0:00:01
#      -----------------------------            5.6/7.6 MB 17.1 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.6 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 18.8 MB/s eta 0:00:00
# ...
#                                               0.0/470.9 kB ? eta -:--:--
#      ------------------------------------- 470.9/470.9 kB 28.8 MB/s eta 0:00:00
# ...

# %%
# 추가 seaborn 설치
# !pip install seaborn
# Out:
# ...
#                                               0.0/293.3 kB ? eta -:--:--
#      ----                                    30.7/293.3 kB 1.3 MB/s eta 0:00:01
#      ----------                              81.9/293.3 kB 1.2 MB/s eta 0:00:01
#      -----------------------------          225.3/293.3 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 2.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### matplotlib 사용

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.random.randn(30).cumsum()
arr
# Out:
# array([ 1.43750837,  0.69960973,  1.10922368,  1.02233592,  2.25329646,
#         1.90371417,  0.5885307 ,  0.82045932,  0.68283769,  0.17299395,
#         0.19814942,  0.50828187, -0.56359983, -0.80031661, -1.63439973,
#        -0.94444398, -0.17554344, -0.35433911, -0.45820455,  1.46514297,
#         1.40721195,  1.096143  ,  0.25111678,  0.32641127,  0.73042304,
#        -0.81159889,  0.64298539, -0.30842882, -0.58234478, -2.2149544 ])

# %%
# 단일 차트
plt.plot(arr)

# %%
# 다중차트
fig = plt.figure() # Figure 객체 생성
ax1 = fig.add_subplot(2, 2, 1) # 차트1(2행 2열로 차트중 1)
ax2 = fig.add_subplot(2, 2, 2) # 차트2(2행 2열로 차트중 2)
ax3 = fig.add_subplot(2, 2, 4) # 차트3(2행 2열로 차트중 3)

ax1.hist(np.random.randn(100)) # 분포표
ax2.scatter(np.arange(30), np.random.randn(30)) # 스캐터차트
ax3.plot(np.random.randn(50).cumsum())  # 라인차트

plt.show() #차트보기

# %%
# 안쓰는 차트도 나옴
fig, axes = plt.subplots(2, 2)
axes[0][0].hist(np.random.randn(100)) # 분포표
axes[0][1].scatter(np.arange(30), np.random.randn(30)) # 스캐터차트
axes[1][1].plot(np.random.randn(50).cumsum())  # 라인차트

plt.show()

# %% [markdown]
# #### 차트꾸미기

# %%
fig, axes = plt.subplots(2, 2)
axes[0][0].hist(np.random.randn(100), bins=20, color='red',alpha=0.5) # bins = 범위 20개로 늘림, alpha = 투명도(0.0[투명]~1.0[불투명])
axes[0][1].scatter(np.arange(30), np.random.randn(30), color='lightgreen') # 스캐터차트
axes[1][0].plot(np.random.randn(50).cumsum(), linestyle=':', color='red', marker='*') # marker =  값위치 표시 *(별), ^(삼각형), o, 1
axes[1][1].plot(np.random.randn(50).cumsum(), linestyle='--', marker='o')  # 라인차트 linestyle = 선종류 -(일반선) --(대시), :(점선), -.(선점)
plt.show()

# %%
# 범례 legend
plt.plot(np.random.randn(50).cumsum(),label='x')
plt.plot(np.random.randn(50).cumsum(),label='y')
plt.legend(loc='center') # 'best' 'upper left', 'upper right', 'lower left', 'lower right', 'right'

plt.show()

# %% [markdown]
# #### Pandas 데이터프레임, 시리즈

# %%
# 판다스 시리즈
pd.Series(np.random.randn(1000).cumsum()).plot()
# Out:
# <Axes: >

# %%
# 데이터 프레임 plot, hist
pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'], index=np.arange(0, 100, 10)).plot()
# Out:
# <Axes: >

# %%
# x, y축 설정
chart = pd.Series(np.random.randn(1000).cumsum()).plot()
chart.set_xticks([0, 250, 500, 750, 1000]) # x축 간격 조정
chart.set_yticks([0, 25, 50]) # x축 간격 조정
chart.set_title('랜덤 Linechart') # 영어는 잘되는데 한글은 기본 깨짐
chart.set_xticklabels(['zero','one','two','three','four'], rotation=90) # x축을 라벨로 표시

plt.show()  #쓸데없는 타입, 결과 메세지 삭제
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47004 (\N{HANGUL SYLLABLE RAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45924 (\N{HANGUL SYLLABLE DEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 한글 깨짐현상
import matplotlib
from matplotlib import font_manager, rc
forn_path = 'C:/Windows/Fonts/HANBatang.ttf'
font = font_manager.FontProperties(fname=forn_path).get_name()
rc('font', family=font) # 한글 깨짐 현상 해결
matplotlib.rcParams['axes.unicode_minus'] = False #한글 사용시 마이너스 꺠짐현상 해결

# x축 y축 설정
chart = pd.Series(np.random.randn(1000).cumsum()).plot()
chart.set_xticks([0, 250, 500, 750, 1000]) # x축 간격 조정
chart.set_yticks([0, 25, 50]) # x축 간격 조정
chart.set_title('랜덤 Linechart') # 영어는 잘되는데 한글은 기본 깨짐
chart.set_xticklabels(['zero','one','two','three','four'], rotation=300) # x축을 라벨로 표시

plt.show()  #쓸데없는 타입, 결과 메세지 삭제

# %% [markdown]
# ##### 예제연습
#
# 캐글 타이타닉 연습문제 CSV
#
# https://raw.githubusercontent.com/developer-sdk/kaggle-python-beginner/master/datas/kaggle-titanic/train.csv

# %%
train = pd.read_csv('https://raw.githubusercontent.com/developer-sdk/kaggle-python-beginner/master/datas/kaggle-titanic/train.csv')

train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#성별 생존률 교차도표 생성
gender_survived = pd.crosstab(train['Sex'], train['Survived'])
gender_survived.columns = gender_survived.columns.map({0:"Dead", 1:"Alive"})

# %%
#bar = gender_survived.plot.bar() #바차트
bar = gender_survived.plot(kind='bar', title='생존자/사망자')

# 차트의 수치표시
for p in bar.patches:
    left, bottom, width, height = p.get_bbox().bounds
    bar.annotate(f'{height:n}', (left+width/2, height*1.02), ha='center')

gender_survived.plot.bar(subplots=True) # 성별로 따로 바차트를 추가 생성
# bar.set_title('생존자/사망자수')
#gender_survived.plot.bar(x= 'Alive') # 차트는 사망자, x축에는 생존자수치 표시(차트와 x라벨을 교차사용 : 쓸일 없음)
gender_survived.plot.bar(x='Dead')

plt.show()

# %%
# 가로 바차트
gender_survived.plot(kind='barh')
gender_survived.plot.barh(subplots=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 라인차트
gender_survived.plot(kind='line')
# Out:
# <Axes: xlabel='Sex'>

# %%
# 파이차트
gender_survived['Alive'].plot(kind='pie', title='생존자 비율', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '생존자 비율'}, ylabel='Alive'>

# %%
gender_survived['Dead'].plot(kind='pie', title='사망자 비율', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '사망자 비율'}, ylabel='Dead'>
