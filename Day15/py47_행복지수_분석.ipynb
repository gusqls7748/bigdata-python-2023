# %% [markdown]
# #### 대한민국 행복지수 분석
#
# ##### 대한민국 행복지도 사이트 접속
#
# 웹사이트 : http://www.happykorea.re.kr/data/data.php?idx=9
# - https로 진입하면 다른 사이트가 나옴
#
# ##### 필요 모듈 임포트

# %%
import matplotlib
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc, rcParams
import seaborn as sns

import pandas as pd
import numpy as np

font_path = 'C:/Windows/Fonts/HanSantteutDotum-Bold.ttf'
font = font_manager.FontProperties(fname=font_path).get_name() # 'NanumGothic'
rc('font', family=font)
rcParams['axes.unicode_minus'] = False

# %%
# 삶의 만족도 로드
df_happylife = pd.read_excel('./raw/대한민국행복지도_삶의만족도.xlsx')
df_happylife
# Out:
#       No       시도    구군  삶의 만족도
# 0      1    서울특별시   종로구  0.4437
# 1      2    서울특별시    중구  0.4976
# 2      3    서울특별시   용산구  0.6161
# 3      4    서울특별시   성동구  0.4729
# 4      5    서울특별시   광진구  0.4041
# ..   ...      ...   ...     ...
# 224  225     경상남도   함양군  0.9565
# 225  226     경상남도   거창군  0.6163
# 226  227     경상남도   합천군  0.8057
# 227  228  제주특별자치도   제주시  0.7113
# 228  229  제주특별자치도  서귀포시  0.7113
#
# [229 rows x 4 columns]

# %%
# 건강 데이터 로드
df_health = pd.read_excel('./raw/대한민국행복지도_건강.xlsx')
df_health
# Out:
#       No       시도    구군      평균  주관적 건강수준 인지율  인구 십만명당 정신건강증진기관 수  \
# 0      1    서울특별시   종로구  0.9220        0.8424              0.6914
# 1      2    서울특별시    중구  0.6742        0.5772              0.4106
# 2      3    서울특별시   용산구  0.5898        0.9819              0.3353
# 3      4    서울특별시   성동구  0.4794        0.5465              0.3321
# 4      5    서울특별시   광진구  0.6373        0.8534              0.7393
# ..   ...      ...   ...     ...           ...                 ...
# 224  225     경상남도   함양군  0.2036        0.0413              0.9857
# 225  226     경상남도   거창군  0.2150        0.4107              0.4134
# 226  227     경상남도   합천군  0.2128        0.0360              0.5756
# 227  228  제주특별자치도   제주시  0.2537        0.4969              0.3854
# 228  229  제주특별자치도  서귀포시  0.2537        0.4969              0.3854
#
#      인구 천명당 의료기관 종사 의사수  건강생활실천율  인구 천명당 의료기관병상수
# 0                1.0000   0.9697          0.7616
# 1                0.9995   0.9669          0.4043
# ...

# %%
# 안전
df_safety = pd.read_excel('./raw/대한민국행복지도_안전.xlsx')
df_safety
# Out:
#       No       시도    구군      평균  사회안전에 대한 인식 b)  인구 천명당 cctv 대수 b)  \
# 0      1    서울특별시   종로구  0.7470          0.9965             0.4796
# 1      2    서울특별시    중구  0.9320          0.9707             0.8214
# 2      3    서울특별시   용산구  0.5537          0.6641             0.4311
# 3      4    서울특별시   성동구  0.5347          0.7452             0.4330
# 4      5    서울특별시   광진구  0.6072          0.7179             0.2196
# ..   ...      ...   ...     ...             ...                ...
# 224  225     경상남도   함양군  0.7012          0.7924             0.5686
# 225  226     경상남도   거창군  0.4392          0.9213             0.3292
# 226  227     경상남도   합천군  0.4268          0.4158             0.6344
# 227  228  제주특별자치도   제주시  0.4461          0.3080             0.7366
# 228  229  제주특별자치도  서귀포시  0.4461          0.3080             0.7366
#
#      인구 십만명당 응급의료기관 및 응급실 운영기관수  단위면적당 지역경찰관서 수  지역안전등급 현황 중 '교통사고 및 화재' a)
# 0                        0.7498          0.9998                      0.0162
# ...

# %%
# 환경
df_environ = pd.read_excel('./raw/대한민국행복지도_환경.xlsx')
df_environ
# Out:
#       No       시도    구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  \
# 0      1    서울특별시   종로구  0.4637    0.4658                 0.7223
# 1      2    서울특별시    중구  0.2865    0.1077                 0.6957
# 2      3    서울특별시   용산구  0.5030    0.3142                 0.7185
# 3      4    서울특별시   성동구  0.4196    0.1480                 0.6868
# 4      5    서울특별시   광진구  0.4992    0.1229                 0.6940
# ..   ...      ...   ...     ...       ...                    ...
# 224  225     경상남도   함양군  0.7717    0.5959                 0.6811
# 225  226     경상남도   거창군  0.7998    0.9610                 0.6259
# 226  227     경상남도   합천군  0.9117    0.9261                 0.6846
# 227  228  제주특별자치도   제주시  0.6842    0.6287                 0.6799
# 228  229  제주특별자치도  서귀포시  0.6842    0.6287                 0.6799
#
#      도시지역 중 '녹지지역 비율'  미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 0              0.2012             0.7704              0.0006
# 1              0.0013             0.6617              0.0000
# ...

# %%
# 경제
df_econ = pd.read_excel('./raw/대한민국행복지도_경제.xlsx')
df_econ
# Out:
#       No       시도    구군      평균  1인당 지역내총생산(GRDP)  인구 천명당 사업체수  인구 천명당 종사자수  \
# 0      1    서울특별시   종로구  1.0000            1.0000       1.0000       1.0000
# 1      2    서울특별시    중구  0.9806            1.0000       1.0000       1.0000
# 2      3    서울특별시   용산구  0.6915            0.6334       0.5493       0.7282
# 3      4    서울특별시   성동구  0.6533            0.5132       0.5368       0.6849
# 4      5    서울특별시   광진구  0.4445            0.2906       0.3424       0.3870
# ..   ...      ...   ...     ...               ...          ...          ...
# 224  225     경상남도   함양군  0.1401            0.3423       0.5130       0.3566
# 225  226     경상남도   거창군  0.1799            0.4873       0.4147       0.3362
# 226  227     경상남도   합천군  0.0373            0.3264       0.3722       0.2689
# 227  228  제주특별자치도   제주시  0.4250            0.4048       0.5553       0.4624
# 228  229  제주특별자치도  서귀포시  0.4250            0.4048       0.5553       0.4624
#
#      국민기초생활보장 수급자비율 a)  종사자 천명당 영세자영업자 수 a)
# ...

# %%
# 교육
df_edu = pd.read_excel('./raw/대한민국행복지도_교육.xlsx')
df_edu
# Out:
#       No       시도    구군      평균  교원 1인당 학생수  영유아 천명당 보육시설 수  인구 십만명당 학교수  \
# 0      1    서울특별시   종로구  0.6839      0.8505          0.6248       0.2249
# 1      2    서울특별시    중구  0.5013      0.8729          0.4147       0.2294
# 2      3    서울특별시   용산구  0.2679      0.6479          0.3804       0.1281
# 3      4    서울특별시   성동구  0.2464      0.7661          0.2270       0.1308
# 4      5    서울특별시   광진구  0.4879      0.9309          0.4263       0.1278
# ..   ...      ...   ...     ...         ...             ...          ...
# 224  225     경상남도   함양군  0.5064      0.1248          0.2642       0.7779
# 225  226     경상남도   거창군  0.8178      0.5177          0.4380       0.7091
# 226  227     경상남도   합천군  0.1640      0.0475          0.1621       0.9273
# 227  228  제주특별자치도   제주시  0.6468      0.7505          0.4032       0.3291
# 228  229  제주특별자치도  서귀포시  0.6468      0.7505          0.4032       0.3291
#
#      인구 천명당 사설학원수
# 0          0.8126
# 1          0.2944
# 2          0.1629
# ...

# %%
# 관계 및 사회참여
df_relation = pd.read_excel('./raw/대한민국행복지도_관계 및 사회참여.xlsx')
df_relation
# Out:
#       No       시도    구군      평균  인구 십만명당 자살률 a)  1인가구(독거노인 제외) 비율 a)  \
# 0      1    서울특별시   종로구  0.7425          0.8318               0.0057
# 1      2    서울특별시    중구  0.4608          0.5462               0.0107
# 2      3    서울특별시   용산구  0.4317          0.7288               0.0211
# 3      4    서울특별시   성동구  0.4182          0.7288               0.0791
# 4      5    서울특별시   광진구  0.3519          0.9434               0.0051
# ..   ...      ...   ...     ...             ...                  ...
# 224  225     경상남도   함양군  0.2192          0.3443               0.8339
# 225  226     경상남도   거창군  0.5717          0.3751               0.8630
# 226  227     경상남도   합천군  0.0510          0.0255               0.8998
# 227  228  제주특별자치도   제주시  0.6107          0.7249               0.3158
# 228  229  제주특별자치도  서귀포시  0.6107          0.7249               0.3158
#
#      독거노인가구 비율 a)  인구 십만명당 사회적기업수  가족관계 만족도 b)
# 0          0.7593          0.9981       0.5949
# ...

# %%
# 여가
df_leisure = pd.read_excel('./raw/대한민국행복지도_여가.xlsx')
df_leisure
# Out:
#       No       시도    구군      평균  여가활용 만족도 b)  노인 천명당 노인여가복지시설수  인구 십만명당 도서관수  \
# 0      1    서울특별시   종로구  0.6331       0.8409            0.1573        0.4523
# 1      2    서울특별시    중구  0.6691       0.6224            0.1467        0.5369
# 2      3    서울특별시   용산구  0.2817       0.6381            0.1628        0.2453
# 3      4    서울특별시   성동구  0.3257       0.5657            0.1859        0.3590
# 4      5    서울특별시   광진구  0.3313       0.6740            0.1443        0.2333
# ..   ...      ...   ...     ...          ...               ...           ...
# 224  225     경상남도   함양군  0.6758       0.1656            0.9794        0.9257
# 225  226     경상남도   거창군  0.4838       0.2433            0.9304        0.4775
# 226  227     경상남도   합천군  0.7900       0.1084            0.9748        0.9949
# 227  228  제주특별자치도   제주시  0.6948       0.8585            0.2026        0.9455
# 228  229  제주특별자치도  서귀포시  0.6948       0.8585            0.2026        0.9455
#
#      인구 십만명당 문화기반시설수  인구 천명당 체육관련 여가시설수
# ...

# %%
# 시도별 데이터 추출
df_city = pd.DataFrame(df_happylife['시도'].unique())
df_city.columns = ['시도']
df_city
# Out:
#          시도
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16  제주특별자치도

# %%
# 삶의 만족도 병합
df_life = df_happylife['삶의 만족도'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_city, df_life, how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도
# 0     서울특별시  0.490972
# 1     부산광역시  0.362081
# 2     대구광역시  0.363988
# 3     인천광역시  0.411480
# 4     광주광역시  0.484480
# 5     대전광역시  0.407580
# 6     울산광역시  0.471980
# 7   세종특별자치시  0.907700
# 8       경기도  0.426023
# 9       강원도  0.619506
# 10     충청북도  0.410100
# 11     충청남도  0.553100
# 12     전라북도  0.608193
# 13     전라남도  0.547709
# 14     경상북도  0.502223
# 15     경상남도  0.530794
# 16  제주특별자치도  0.711300

# %%
df_htemp = df_health['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_htemp.rename('건강'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강
# 0     서울특별시  0.490972  0.569532
# 1     부산광역시  0.362081  0.511906
# 2     대구광역시  0.363988  0.482325
# 3     인천광역시  0.411480  0.339620
# 4     광주광역시  0.484480  0.632300
# 5     대전광역시  0.407580  0.663580
# 6     울산광역시  0.471980  0.420040
# 7   세종특별자치시  0.907700  0.232000
# 8       경기도  0.426023  0.353952
# 9       강원도  0.619506  0.329506
# 10     충청북도  0.410100  0.401064
# 11     충청남도  0.553100  0.347433
# 12     전라북도  0.608193  0.421300
# 13     전라남도  0.547709  0.424732
# 14     경상북도  0.502223  0.264114
# 15     경상남도  0.530794  0.312722
# 16  제주특별자치도  0.711300  0.253700

# %%
# 안전
df_temp = df_safety['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('안전'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전
# 0     서울특별시  0.490972  0.569532  0.552256
# 1     부산광역시  0.362081  0.511906  0.404875
# 2     대구광역시  0.363988  0.482325  0.358429
# 3     인천광역시  0.411480  0.339620  0.421020
# 4     광주광역시  0.484480  0.632300  0.266440
# 5     대전광역시  0.407580  0.663580  0.206780
# 6     울산광역시  0.471980  0.420040  0.477060
# 7   세종특별자치시  0.907700  0.232000  0.157800
# 8       경기도  0.426023  0.353952  0.325255
# 9       강원도  0.619506  0.329506  0.548000
# 10     충청북도  0.410100  0.401064  0.573155
# 11     충청남도  0.553100  0.347433  0.481313
# 12     전라북도  0.608193  0.421300  0.410914
# 13     전라남도  0.547709  0.424732  0.565195
# 14     경상북도  0.502223  0.264114  0.484835
# 15     경상남도  0.530794  0.312722  0.475561
# 16  제주특별자치도  0.711300  0.253700  0.446100

# %%
# 환경
df_temp = df_environ['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('환경'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400
# 8       경기도  0.426023  0.353952  0.325255  0.557977
# 9       강원도  0.619506  0.329506  0.548000  0.639839
# 10     충청북도  0.410100  0.401064  0.573155  0.466045
# 11     충청남도  0.553100  0.347433  0.481313  0.558173
# 12     전라북도  0.608193  0.421300  0.410914  0.670586
# 13     전라남도  0.547709  0.424732  0.565195  0.700573
# 14     경상북도  0.502223  0.264114  0.484835  0.614265
# 15     경상남도  0.530794  0.312722  0.475561  0.735600
# 16  제주특별자치도  0.711300  0.253700  0.446100  0.684200

# %%
# 경제
df_temp = df_econ['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('경제'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893
# 12     전라북도  0.608193  0.421300  0.410914  0.670586  0.196543
# 13     전라남도  0.547709  0.424732  0.565195  0.700573  0.202668
# ...

# %%
# 교육
df_temp = df_edu['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('교육'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제        교육
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260  0.840780
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580  0.763240
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900  0.587000
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926  0.668619
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861  0.488533
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047
# ...

# %%
# 관계 및 사회참여
df_temp = df_relation['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('관계및사회참여'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제        교육  \
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260  0.840780
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580  0.763240
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900  0.587000
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926  0.668619
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861  0.488533
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047
# ...

# %%
# 여가
df_temp = df_leisure['평균'].groupby(by=df_happylife['시도']).mean() # 각 시도별 평균내서 17개로 그룹핑
df_happy_merge = pd.merge(df_happy_merge, df_temp.rename('여가'), how='left', on='시도')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제        교육  \
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260  0.840780
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580  0.763240
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900  0.587000
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926  0.668619
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861  0.488533
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047
# ...

# %%
df_happy_merge.to_excel('./대한민국_시도별_행복지수.xlsx', index=False)

# %% [markdown]
# ##### 검산

# %%
df_happy_merge['삶의 만족도'].mean()
# Out:
# 0.5181887062335198

# %%
df_happylife['삶의 만족도'].mean()
# Out:
# 0.4937618421052632

# %%
df_happy_merge = pd.read_excel('./대한민국_시도별_행복지수.xlsx')
df_happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제        교육  \
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260  0.840780
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580  0.763240
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900  0.587000
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926  0.668619
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861  0.488533
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047
# ...

# %%
df_happy_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시도       17 non-null     object
#  1   삶의 만족도   17 non-null     float64
#  2   건강       17 non-null     float64
#  3   안전       17 non-null     float64
#  4   환경       17 non-null     float64
#  5   경제       17 non-null     float64
#  6   교육       17 non-null     float64
#  7   관계및사회참여  17 non-null     float64
#  8   여가       17 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 1.3+ KB

# %%
df_happy_merge.describe()
# Out:
#           삶의 만족도         건강         안전         환경         경제         교육  \
# count  17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean    0.518189   0.409401   0.420882   0.579406   0.407635   0.578653
# std     0.138257   0.127636   0.123557   0.097299   0.111265   0.125408
# min     0.362081   0.232000   0.157800   0.393440   0.196543   0.399412
# 25%     0.411480   0.329506   0.358429   0.515020   0.386861   0.488533
# 50%     0.490972   0.401064   0.446100   0.582380   0.410820   0.587000
# 75%     0.553100   0.482325   0.484835   0.652400   0.468926   0.648047
# max     0.907700   0.663580   0.573155   0.735600   0.642580   0.840780
#
#          관계및사회참여         여가
# count  17.000000  17.000000
# mean    0.497632   0.464910
# std     0.114394   0.176206
# min     0.294719   0.153587
# 25%     0.402183   0.347960
# 50%     0.487464   0.454980
# 75%     0.601532   0.632750
# max     0.676440   0.702891

# %%
df_happy_value = df_happy_merge[['삶의 만족도','건강','안전','환경','경제','교육','관계및사회참여','여가']]
df_happy_value
# Out:
#       삶의 만족도        건강        안전        환경        경제        교육   관계및사회참여  \
# 0   0.490972  0.569532  0.552256  0.470712  0.532820  0.399412  0.390656
# 1   0.362081  0.511906  0.404875  0.448719  0.438038  0.504594  0.294719
# 2   0.363988  0.482325  0.358429  0.552500  0.393975  0.585838  0.407486
# 3   0.411480  0.339620  0.421020  0.515020  0.410820  0.502920  0.504920
# 4   0.484480  0.632300  0.266440  0.607480  0.387380  0.689680  0.637800
# 5   0.407580  0.663580  0.206780  0.582380  0.416260  0.840780  0.510820
# 6   0.471980  0.420040  0.477060  0.393440  0.642580  0.763240  0.676440
# 7   0.907700  0.232000  0.157800  0.652400  0.511900  0.587000  0.673700
# 8   0.426023  0.353952  0.325255  0.557977  0.468926  0.668619  0.601532
# 9   0.619506  0.329506  0.548000  0.639839  0.386861  0.488533  0.563122
# 10  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409  0.372782
# 11  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047  0.448720
# ...

# %%
df_happy_value.mean(axis=0) # axis=0 열
# Out:
# 삶의 만족도     0.518189
# 건강         0.409401
# 안전         0.420882
# 환경         0.579406
# 경제         0.407635
# 교육         0.578653
# 관계및사회참여    0.497632
# 여가         0.464910
# dtype: float64

# %%
# df_happy_value.mean(axis=1) # axis=1 행
df_happy_merge.set_index('시도').mean(axis=1)
# Out:
# 시도
# 서울특별시      0.461637
# 부산광역시      0.389815
# 대구광역시      0.422433
# 인천광역시      0.418799
# 광주광역시      0.520068
# 대전광역시      0.497017
# 울산광역시      0.532900
# 세종특별자치시    0.521288
# 경기도        0.472481
# 강원도        0.526015
# 충청북도       0.500400
# 충청남도       0.508128
# 전라북도       0.488729
# 전라남도       0.500111
# 경상북도       0.436254
# 경상남도       0.482856
# 제주특별자치도    0.559075
# dtype: float64

# %%
# 분석 상관관계 함수
# + 양의관계(수치가 오르면 관계도 높아짐), - 음의관계(수치 올라가면 관계내려감)
# 0~1, 0.1이하(거의 관계없음), 0.15~0.4(약간관계), 0.5~(높은 관계), 1(자기자신의 데이터와 상관관계)
df_happy_value.corr()
# Out:
#            삶의 만족도        건강        안전        환경        경제        교육   관계및사회참여  \
# 삶의 만족도   1.000000 -0.570466 -0.191709  0.572262 -0.057815 -0.113522  0.519122
# 건강      -0.570466  1.000000 -0.210138 -0.357841  0.071809  0.242186 -0.175048
# 안전      -0.191709 -0.210138  1.000000 -0.124581 -0.142781 -0.519065 -0.444827
# 환경       0.572262 -0.357841 -0.124581  1.000000 -0.716187 -0.146646  0.169838
# 경제      -0.057815  0.071809 -0.142781 -0.716187  1.000000  0.451395  0.298562
# 교육      -0.113522  0.242186 -0.519065 -0.146646  0.451395  1.000000  0.462585
# 관계및사회참여  0.519122 -0.175048 -0.444827  0.169838  0.298562  0.462585  1.000000
# 여가       0.497880 -0.405151  0.382730  0.494416 -0.367461 -0.070109  0.216653
#
#                여가
# 삶의 만족도   0.497880
# 건강      -0.405151
# 안전       0.382730
# 환경       0.494416
# 경제      -0.367461
# 교육      -0.070109
# 관계및사회참여  0.216653
# 여가       1.000000

# %% [markdown]
# ##### 시각화

# %%
# 선그래프 시각화
plt.figure(figsize=(15,6))
plt.title('대한민국 행복지수')
items = list(df_happy_merge.columns[1:9])
for item in items:
    data = df_happy_merge[item]
    plt.plot(data, marker='o', label=item)

plt.xlabel('시도')
plt.ylabel('수치')
plt.xticks(range(17), df_happy_merge['시도'], fontsize=8)
plt.legend() 
plt.grid()
plt.show()

# %%
# 막대 그래프
df_happy_merge.plot(kind='bar', xlabel='시도', ylabel='수치', figsize=(15, 20), grid=True, subplots=True)

plt.suptitle('대한민국 행복지수', fontsize=20)
plt.tight_layout(pad=8, h_pad=2)
plt.xticks(range(17), df_happy_merge['시도'])
plt.show()

# %%
# 히트맵
plt.figure(figsize=(15,13))
plt.title('대한민국 행복지수 상관관계', fontsize=20)

corr_mat = df_happy_value.corr()
upp_mat = np.triu(corr_mat)
sns.heatmap(corr_mat, mask=upp_mat, annot=True, cmap='RdYlGn')
plt.show()
